# %% [markdown]
# # HW1: Giới thiệu CUDA

# %% [markdown]
# Với các GPU tương đối mới thì để biên dịch chỉ cần dùng câu lệnh: \
# `nvcc tên-file.cu -o tên-file-chạy`
#
# Nhưng trên Colab mình thường lấy được GPU khá cũ là Tesla K80 với compute capability (phiên bản phần cứng) là 3.7; để biên dịch đúng với GPU khá cũ này thì bạn cần dùng câu lệnh: \
# `nvcc -arch=sm_37 tên-file.cu -o tên-file-chạy` \
# Trong đó, 37 chính là compute capability của GPU Tesla K80.
#
# Để phòng trường hợp khi làm bài bạn lấy được GPU có compute capability x.x nhưng khi chấm bài Thầy lại lấy được GPU có compute capability khác x.x, dưới đây mình sẽ có đoạn code Python để tự động lấy 2 con số ứng với compute capability của GPU và lưu vào 2 biến `major` và `minor`:

# %%
from numba import cuda
major, minor = cuda.get_current_device().compute_capability
print(f'GPU compute capability: {major}.{minor}')
# Out:
# GPU compute capability: 7.5

# %% [markdown]
# Một khi đã chạy đoạn code Python ở trên, để biên dịch thì bạn sẽ dùng câu lệnh: \
# `nvcc -arch=sm_{major}{minor} tên-file.cu -o tên-file-chạy`

# %% [markdown]
# ## Câu 1

# %%
# !nvcc -arch=sm_{major}{minor} HW1_P1.cu -o HW1_P1

# %%
# !./HW1_P1 in.pnm out.pnm
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 2.582496 ms
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Processing time (use device): 1.125664 ms
#
# Error between device result and host result: 0.002674

# %% [markdown]
# Chạy với các kích thước khác nhau

# %%
# !./HW1_P1 in.pnm out16x16.pnm 16 16
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 2.213888 ms
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Processing time (use device): 0.872480 ms
#
# Error between device result and host result: 0.002674

# %%
# !./HW1_P1 in.pnm out32x32.pnm 32 32
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 2.283296 ms
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Processing time (use device): 0.888224 ms
#
# Error between device result and host result: 0.002674

# %% [markdown]
# Lỗi khi chạy với block kích thước 64x64

# %%
# !./HW1_P1 in.pnm out64x64.pnm 64 64
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 2.254944 ms
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Sync Error: invalid configuration argument
# Processing time (use device): 0.896992 ms
#
# Error between device result and host result: 119.969627

# %% [markdown]
# ## Câu 2

# %%
# !nvcc -arch=sm_{major}{minor} HW1_P2.cu -o HW1_P2

# %%
# !./HW1_P2 in.pnm out2.pnm out2_target.pnm
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 354.725891 ms
# Error: 0.000000
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Processing time (use device): 2.915840 ms
# Error: 0.000703

# %%
# !./HW1_P2 in.pnm out2_16x16.pnm out2_target.pnm 16 16
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 352.118652 ms
# Error: 0.000000
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Processing time (use device): 2.313344 ms
# Error: 0.000703

# %%
# !./HW1_P2 in.pnm out2_64x64.pnm out2_target.pnm 64 64
# Out:
# Image size (width x height): 512 x 512
#
# Processing time (use host): 349.833435 ms
# Error: 0.000000
#
# GPU name: Tesla T4
# GPU compute capability: 7.5
# Sync Error: invalid configuration argument
# Processing time (use device): 1.731264 ms
# Error: 124.033791
